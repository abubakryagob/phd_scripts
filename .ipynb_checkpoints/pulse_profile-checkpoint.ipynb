# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading the data
file1_03_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/1801_pulse_profile_0.3-10kev.txt"
Data1_03_10 = np.loadtxt(file1_03_10)
phase1_03_10 = Data1_03_10[:,0]
bin_simi_width1_03_10 = Data1_03_10[:,1]
intensity1_03_10 = Data1_03_10[:,2]
model_normalization1_03_10 = Data1_03_10[:,3]

file1_03_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/1801_pulse_profile_0.3-3kev.txt"
Data1_03_3 = np.loadtxt(file1_03_3)
phase1_03_3 = Data1_03_3[:,0]
bin_simi_width1_03_3 = Data1_03_3[:,1]
intensity1_03_3 = Data1_03_3[:,2]
model_normalization1_03_3 = Data1_03_3[:,3]

file1_3_6 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/1801_pulse_profile_3-6kev.txt"
Data1_3_6 = np.loadtxt(file1_3_6)
phase1_3_6 = Data1_3_6[:,0]
bin_simi_width1_3_6 = Data1_3_6[:,1]
intensity1_3_6 = Data1_3_6[:,2]
model_normalization1_3_6 = Data1_3_6[:,3]

file1_6_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/1801_pulse_profile_6-10kev_16bin.txt"
Data1_6_10 = np.loadtxt(file1_6_10)
phase1_6_10 = Data1_6_10[:,0]
bin_simi_width1_6_10 = Data1_6_10[:,1]
intensity1_6_10 = Data1_6_10[:,2]
model_normalization1_6_10 = Data1_6_10[:,3]

# %%
plt.style.use('seaborn-notebook')
plt.figure(figsize=(10,7), dpi=80)

plt.errorbar(phase1_03_10, intensity1_03_10, xerr=bin_simi_width1_03_10, yerr=model_normalization1_03_10,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')


plt.errorbar(phase1_03_3, intensity1_03_3+1.5, xerr=bin_simi_width1_03_3, yerr=model_normalization1_03_3,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')



plt.errorbar(phase1_3_6, intensity1_3_6+3, xerr=bin_simi_width1_3_6, yerr=model_normalization1_3_6,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')


plt.errorbar(phase1_6_10, intensity1_6_10+4.5, xerr=bin_simi_width1_6_10, yerr=model_normalization1_6_10,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')


plt.title('J18181 Pulse profile_Obs.ID1801', fontsize=18)
plt.xlabel("Phase (cycle)")
plt.ylabel("Normalized Intensity")
plt.legend(bbox_to_anchor=(1,0), loc="lower right", 
                bbox_transform=fig.transFigure, ncol=4)
plt.savefig('SWJ1818_pulse_profile_1801.pdf', bbox_inches = 'tight')
plt.show()

# %%
#Reading the data
file2_03_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/3901_pulse_profile_0.3-10.txt"
Data2_03_10 = np.loadtxt(file2_03_10)
phase2_03_10 = Data2_03_10[:,0]
bin_simi_width2_03_10 = Data1_03_10[:,1]
intensity2_03_10 = Data2_03_10[:,2]
model_normalization2_03_10 = Data2_03_10[:,3]

file2_03_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/3901_pulse_profile_0.3-3kev.txt"
Data2_03_3 = np.loadtxt(file2_03_3)
phase2_03_3 = Data2_03_3[:,0]
bin_simi_width2_03_3 = Data2_03_3[:,1]
intensity2_03_3 = Data2_03_3[:,2]
model_normalization2_03_3 = Data2_03_3[:,3]

file2_3_6 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/3901_pulse_profile_3-6kev.txt"
Data2_3_6 = np.loadtxt(file2_3_6)
phase2_3_6 = Data2_3_6[:,0]
bin_simi_width2_3_6 = Data2_3_6[:,1]
intensity2_3_6 = Data2_3_6[:,2]
model_normalization2_3_6 = Data2_3_6[:,3]

file2_6_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/3901_pulse_profile_6-10kev.txt"
Data2_6_10 = np.loadtxt(file2_6_10)
phase2_6_10 = Data2_6_10[:,0]
bin_simi_width2_6_10 = Data2_6_10[:,1]
intensity2_6_10 = Data2_6_10[:,2]
model_normalization2_6_10 = Data2_6_10[:,3]

# %%
plt.style.use('seaborn-notebook')
plt.figure(figsize=(10,7), dpi=80)

plt.errorbar(phase2_03_10, intensity2_03_10, xerr=bin_simi_width2_03_10, yerr=model_normalization2_03_10,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')


plt.errorbar(phase2_03_3, intensity2_03_3+1.5, xerr=bin_simi_width2_03_3, yerr=model_normalization2_03_3,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')



plt.errorbar(phase2_3_6, intensity2_3_6+3, xerr=bin_simi_width2_3_6, yerr=model_normalization2_3_6,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')


plt.errorbar(phase2_6_10, intensity2_6_10+4.5, xerr=bin_simi_width2_6_10, yerr=model_normalization2_6_10,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')


plt.title('J18181 Pulse profile_Obs.ID3901', fontsize=18)
plt.xlabel("Phase (cycle)")
plt.ylabel("Normalized Intensity")
plt.legend(bbox_to_anchor=(1,0), loc="lower right", 
                bbox_transform=fig.transFigure, ncol=4)
plt.savefig('SWJ1818_pulse_profile_3901.pdf', bbox_inches = 'tight')
plt.show()

# %%
#Reading the data
file3_03_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/4001_pulse_profile_0.3-10kev.txt"
Data3_03_10 = np.loadtxt(file3_03_10)
phase3_03_10 = Data3_03_10[:,0]
bin_simi_width3_03_10 = Data3_03_10[:,1]
intensity3_03_10 = Data3_03_10[:,2]
model_normalization3_03_10 = Data3_03_10[:,3]

file3_03_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/4001_pulse_profile_0.3-3kev.txt"
Data3_03_3 = np.loadtxt(file3_03_3)
phase3_03_3 = Data3_03_3[:,0]
bin_simi_width3_03_3 = Data3_03_3[:,1]
intensity3_03_3 = Data3_03_3[:,2]
model_normalization3_03_3 = Data3_03_3[:,3]

file3_3_6 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/4001_pulse_profile_3-6kev.txt"
Data3_3_6 = np.loadtxt(file3_3_6)
phase3_3_6 = Data3_3_6[:,0]
bin_simi_width3_3_6 = Data3_3_6[:,1]
intensity3_3_6 = Data3_3_6[:,2]
model_normalization3_3_6 = Data3_3_6[:,3]

file3_6_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/4001_pulse_profile_6-10kev.txt"
Data3_6_10 = np.loadtxt(file3_6_10)
phase3_6_10 = Data3_6_10[:,0]
bin_simi_width3_6_10 = Data3_6_10[:,1]
intensity3_6_10 = Data3_6_10[:,2]
model_normalization3_6_10 = Data3_6_10[:,3]

# %%
plt.style.use('seaborn-notebook')
plt.figure(figsize=(10,7), dpi=80)

plt.errorbar(phase3_03_10, intensity3_03_10, xerr=bin_simi_width3_03_10, yerr=model_normalization3_03_10,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')


plt.errorbar(phase3_03_3, intensity3_03_3+1.5, xerr=bin_simi_width3_03_3, yerr=model_normalization3_03_3,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')



plt.errorbar(phase3_3_6, intensity3_3_6+3, xerr=bin_simi_width3_3_6, yerr=model_normalization3_3_6,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')


plt.errorbar(phase3_6_10, intensity3_6_10+4.5, xerr=bin_simi_width3_6_10, yerr=model_normalization3_6_10,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')


plt.title('J18181 Pulse profile_Obs.ID4001', fontsize=18)
plt.xlabel("Phase (cycle)")
plt.ylabel("Normalized Intensity")
plt.legend(bbox_to_anchor=(1,0), loc="lower right", 
                bbox_transform=fig.transFigure, ncol=4)
plt.savefig('SWJ1818_pulse_profile_4001.pdf', bbox_inches = 'tight')
plt.show()

# %%
#Reading the data
file4_03_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/4201_pulse_profile_0.3-10kev.txt"
Data4_03_10 = np.loadtxt(file4_03_10)
phase4_03_10 = Data4_03_10[:,0]
bin_simi_width4_03_10 = Data4_03_10[:,1]
intensity4_03_10 = Data4_03_10[:,2]
model_normalization4_03_10 = Data4_03_10[:,3]

file4_03_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/4201_pulse_profile_0.3-3kev.txt"
Data4_03_3 = np.loadtxt(file4_03_3)
phase4_03_3 = Data4_03_3[:,0]
bin_simi_width4_03_3 = Data4_03_3[:,1]
intensity4_03_3 = Data4_03_3[:,2]
model_normalization4_03_3 = Data4_03_3[:,3]

file4_3_6 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/4201_pulse_profile_3-6kev.txt"
Data4_3_6 = np.loadtxt(file4_3_6)
phase4_3_6 = Data4_3_6[:,0]
bin_simi_width4_3_6 = Data4_3_6[:,1]
intensity4_3_6 = Data4_3_6[:,2]
model_normalization4_3_6 = Data4_3_6[:,3]

file4_6_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/4201_pulse_profile_6-10kev.txt"
Data4_6_10 = np.loadtxt(file4_6_10)
phase4_6_10 = Data4_6_10[:,0]
bin_simi_width4_6_10 = Data4_6_10[:,1]
intensity4_6_10 = Data4_6_10[:,2]
model_normalization4_6_10 = Data4_6_10[:,3]

# %%
plt.style.use('seaborn-notebook')
plt.figure(figsize=(10,7), dpi=80)

plt.errorbar(phase4_03_10, intensity4_03_10, xerr=bin_simi_width4_03_10, yerr=model_normalization4_03_10,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')


plt.errorbar(phase4_03_3, intensity4_03_3+1.5, xerr=bin_simi_width4_03_3, yerr=model_normalization4_03_3,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')



plt.errorbar(phase4_3_6, intensity4_3_6+3, xerr=bin_simi_width4_3_6, yerr=model_normalization4_3_6,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')


plt.errorbar(phase4_6_10, intensity4_6_10+4.5, xerr=bin_simi_width4_6_10, yerr=model_normalization4_6_10,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')


plt.title('J18181 Pulse profile_Obs.ID4201', fontsize=18)
plt.xlabel("Phase (cycle)")
plt.ylabel("Normalized Intensity")
plt.legend(bbox_to_anchor=(1,0), loc="lower right", 
                bbox_transform=fig.transFigure, ncol=4)
plt.savefig('SWJ1818_pulse_profile_4201.pdf', bbox_inches = 'tight')
plt.show()

# %%
file2= "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/3901_pulse_profile_0.3-3kev.txt"
Data2 = np.loadtxt(file2)
phase2 = Data2[:,0]
bin_simi_width2 = Data2[:,1]
intensity2 = Data2[:,2]
model_normalization2 = Data2[:,3]

# %%
file3= "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/4001_pulse_profile_0.3-3kev.txt"
Data3 = np.loadtxt(file3)
phase3 = Data3[:,0]
bin_simi_width3 = Data3[:,1]
intensity3 = Data3[:,2]
model_normalization3 = Data3[:,3]

# %%
file4= "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/4201_pulse_profile_0.3-3kev.txt"
Data4 = np.loadtxt(file4)
phase4 = Data4[:,0]
bin_simi_width4 = Data4[:,1]
intensity4 = Data4[:,2]
model_normalization4 = Data4[:,3]

# %%
# Implementation of matplotlib function
import numpy as np
import matplotlib.pyplot as plt
   
fig = plt.figure()

plt.errorbar(phase, intensity, xerr=bin_simi_width, yerr=model_normalization,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')

plt.errorbar(phase2, intensity2, xerr=bin_simi_width2, yerr=model_normalization2,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')

plt.errorbar(phase3, intensity3, xerr=bin_simi_width3, yerr=model_normalization3,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')

plt.errorbar(phase4, intensity4, xerr=bin_simi_width4, yerr=model_normalization4,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')
   
plt.legend(loc ='upper left')
  
plt.title('matplotlib.pyplot.errorbar()\
function Example')
plt.show()

# %%
# Now switch to a more OO interface to exercise more features.
fig, axs = plt.subplots(nrows=2, ncols=2, sharex=True)

ax = axs[0, 0]
ax.errorbar(phase, intensity, xerr=bin_simi_width, yerr=model_normalization,
            fmt = '.', fillstyle = 'none', mec='black', mew = 2, ms=3, color='black', label = '0.3-10 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")

# With 4 subplots, reduce the number of axis ticks to avoid crowding.
ax.locator_params(nbins=4)

ax = axs[0, 1]
ax.errorbar(phase2, intensity2, xerr=bin_simi_width2, yerr=model_normalization2,
            fmt = '.', fillstyle = 'none', mec='red', mew = 2, ms=3, color='red', label = '0.3-3 keV')


ax = axs[1, 0]
ax.errorbar(phase3, intensity3, xerr=bin_simi_width3, yerr=model_normalization3,
            fmt = '.', fillstyle = 'none', mec='c', mew = 2, ms=3, color='c', label = '3-6 keV')

ax = axs[1, 1]
ax.set_yscale('log')
ax.errorbar(phase4, intensity4, xerr=bin_simi_width4, yerr=model_normalization4,
            fmt = '.', fillstyle = 'none', mec='m', mew = 2, ms=3, color='m', label = '6-10 keV')

fig.suptitle('Variable errorbars') 
fig.show()
# Out:
# <ipython-input-183-f05af429f742>:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## New plotting

# %%
#Reading the data
file1_03_10new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_0.3-10kev.qdp"
Data1_03_10new = np.loadtxt(file1_03_10new)
phase1_03_10new = Data1_03_10new[:,0]
bin_simi_width1_03_10new = Data1_03_10new[:,1]
intensity1_03_10new = Data1_03_10new[:,2]
model_normalization1_03_10new = Data1_03_10new[:,3]

file1_03_1new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_0.3-1kev_16.qdp"
Data1_03_1new = np.loadtxt(file1_03_1new)
phase1_03_1new = Data1_03_1new[:,0]
bin_simi_width1_03_1new = Data1_03_1new[:,1]
intensity1_03_1new = Data1_03_1new[:,2]
model_normalization1_03_1new = Data1_03_1new[:,3]


#file1_1_2 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_1-2kev.qdp"
#Data1_1_2 = np.loadtxt(file1_1_2)
#phase1_1_2 = Data1_1_2[:,0]
#bin_simi_width1_1_2 = Data1_1_2[:,1]
#intensity1_1_2 = Data1_1_2[:,2]
#model_normalization1_1_2 = Data1_1_2[:,3]

file1_2_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_2-3kev.qdp"
Data1_2_3 = np.loadtxt(file1_2_3)
phase1_2_3 = Data1_2_3[:,0]
bin_simi_width1_2_3 = Data1_2_3[:,1]
intensity1_2_3 = Data1_2_3[:,2]
model_normalization1_2_3 = Data1_2_3[:,3]

file1_3_5 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_3-5kev.qdp"
Data1_3_5  = np.loadtxt(file1_3_5 )
phase1_3_5  = Data1_3_5 [:,0]
bin_simi_width1_3_5  = Data1_3_5 [:,1]
intensity1_3_5  = Data1_3_5 [:,2]
model_normalization1_3_5  = Data1_3_5 [:,3]

file1_5_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_5-10kev.qdp"
Data1_5_10 = np.loadtxt(file1_5_10)
phase1_5_10 = Data1_5_10[:,0]
bin_simi_width1_5_10 = Data1_5_10[:,1]
intensity1_5_10 = Data1_5_10[:,2]
model_normalization1_5_10 = Data1_5_10[:,3]

# %%
#Reading the data
file2_03_10new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/new/PNclean_barry_source_filtered_0.3-10kev-32bin.qdp"
Data2_03_10new = np.loadtxt(file2_03_10new)
phase2_03_10new = Data2_03_10new[:,0]
bin_simi_width2_03_10new = Data2_03_10new[:,1]
intensity2_03_10new = Data2_03_10new[:,2]
model_normalization2_03_10new = Data2_03_10new[:,3]

file2_03_2new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/new/PNclean_barry_source_filtered_0.3-2kev.qdp"
Data2_03_2new = np.loadtxt(file2_03_2new)
phase2_03_2new = Data2_03_2new[:,0]
bin_simi_width2_03_2new = Data2_03_2new[:,1]
intensity2_03_2new = Data2_03_2new[:,2]
model_normalization2_03_2new = Data2_03_2new[:,3]


#file1_1_2 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_1-2kev.qdp"
#Data1_1_2 = np.loadtxt(file1_1_2)
#phase1_1_2 = Data1_1_2[:,0]
#bin_simi_width1_1_2 = Data1_1_2[:,1]
#intensity1_1_2 = Data1_1_2[:,2]
#model_normalization1_1_2 = Data1_1_2[:,3]

file2_2_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/new/PNclean_barry_source_filtered_2-3kev.qdp"
Data2_2_3 = np.loadtxt(file2_2_3)
phase2_2_3 = Data2_2_3[:,0]
bin_simi_width2_2_3 = Data2_2_3[:,1]
intensity2_2_3 = Data2_2_3[:,2]
model_normalization2_2_3 = Data2_2_3[:,3]

file2_3_5 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/new/PNclean_barry_source_filtered_3-5kev.qdp"
Data2_3_5  = np.loadtxt(file2_3_5 )
phase2_3_5  = Data2_3_5 [:,0]
bin_simi_width2_3_5  = Data2_3_5 [:,1]
intensity2_3_5  = Data2_3_5 [:,2]
model_normalization2_3_5  = Data2_3_5 [:,3]

file2_5_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/3901/new/PNclean_barry_source_filtered_5-10kev_32.qdp"
Data2_5_10 = np.loadtxt(file2_5_10)
phase2_5_10 = Data2_5_10[:,0]
bin_simi_width2_5_10 = Data2_5_10[:,1]
intensity2_5_10 = Data2_5_10[:,2]
model_normalization2_5_10 = Data2_5_10[:,3]

# %%
#Reading the data
file3_03_10new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_0.3-10kev_32bin.qdp"
Data3_03_10new = np.loadtxt(file3_03_10new)
phase3_03_10new = Data3_03_10new[:,0]
bin_simi_width3_03_10new = Data3_03_10new[:,1]
intensity3_03_10new = Data3_03_10new[:,2]
model_normalization3_03_10new = Data3_03_10new[:,3]

file3_03_2new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_0.3-2kev.qdp"
Data3_03_2new = np.loadtxt(file3_03_2new)
phase3_03_2new = Data3_03_2new[:,0]
bin_simi_width3_03_2new = Data3_03_2new[:,1]
intensity3_03_2new = Data3_03_2new[:,2]
model_normalization3_03_2new = Data3_03_2new[:,3]


#file1_1_2 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_1-2kev.qdp"
#Data1_1_2 = np.loadtxt(file1_1_2)
#phase1_1_2 = Data1_1_2[:,0]
#bin_simi_width1_1_2 = Data1_1_2[:,1]
#intensity1_1_2 = Data1_1_2[:,2]
#model_normalization1_1_2 = Data1_1_2[:,3]

file3_2_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_2-3kev_16bin.qdp"
Data3_2_3 = np.loadtxt(file3_2_3)
phase3_2_3 = Data3_2_3[:,0]
bin_simi_width3_2_3 = Data3_2_3[:,1]
intensity3_2_3 = Data3_2_3[:,2]
model_normalization3_2_3 = Data3_2_3[:,3]

file3_3_5 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_3-5kev_32.qdp"
Data3_3_5  = np.loadtxt(file3_3_5 )
phase3_3_5  = Data3_3_5 [:,0]
bin_simi_width3_3_5  = Data3_3_5 [:,1]
intensity3_3_5  = Data3_3_5 [:,2]
model_normalization3_3_5  = Data3_3_5 [:,3]

file3_5_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_5-10kev.qdp"
Data3_5_10 = np.loadtxt(file3_5_10)
phase3_5_10 = Data3_5_10[:,0]
bin_simi_width3_5_10 = Data3_5_10[:,1]
intensity3_5_10 = Data3_5_10[:,2]
model_normalization3_5_10 = Data3_5_10[:,3]

# %%
#Reading the data
file4_03_10new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4001/new/PNclean_barry_source_filtered_0.3-10kev_32bin.qdp"
Data4_03_10new = np.loadtxt(file4_03_10new)
phase4_03_10new = Data4_03_10new[:,0]
bin_simi_width4_03_10new = Data4_03_10new[:,1]
intensity4_03_10new = Data4_03_10new[:,2]
model_normalization4_03_10new = Data4_03_10new[:,3]

#file4_03_2new = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/new/PNclean_barry_source_filtered_0.3"
Data4_03_2new = np.loadtxt(file4_03_2new)
phase4_03_2new = Data4_03_2new[:,0]
bin_simi_width4_03_2new = Data4_03_2new[:,1]
intensity4_03_2new = Data4_03_2new[:,2]
model_normalization4_03_2new = Data4_03_2new[:,3]


#file1_1_2 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/1801/new/PNclean_barry_source_filtered_1-2kev.qdp"
#Data1_1_2 = np.loadtxt(file1_1_2)
#phase1_1_2 = Data1_1_2[:,0]
#bin_simi_width1_1_2 = Data1_1_2[:,1]
#intensity1_1_2 = Data1_1_2[:,2]
#model_normalization1_1_2 = Data1_1_2[:,3]

file4_2_3 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/new/PNclean_barry_source_filtered_2-3kev.qdp"
Data4_2_3 = np.loadtxt(file4_2_3)
phase4_2_3 = Data4_2_3[:,0]
bin_simi_width4_2_3 = Data4_2_3[:,1]
intensity4_2_3 = Data4_2_3[:,2]
model_normalization4_2_3 = Data4_2_3[:,3]

file4_3_5 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/new/PNclean_barry_source_filtered_3-5kev_16bin.qdp"
Data4_3_5  = np.loadtxt(file4_3_5 )
phase4_3_5  = Data4_3_5 [:,0]
bin_simi_width4_3_5  = Data4_3_5 [:,1]
intensity4_3_5  = Data4_3_5 [:,2]
model_normalization4_3_5  = Data4_3_5 [:,3]

file4_5_10 = "/Users/abubakribrahim/Desktop/observations/xmm-newton/SWJ1818.0-1607/timing_analysis/pulse_profile/4201/new/PNclean_barry_source_filtered_5-10kev_32bin.qdp"
Data4_5_10 = np.loadtxt(file4_5_10)
phase4_5_10 = Data4_5_10[:,0]
bin_simi_width4_5_10 = Data4_5_10[:,1]
intensity4_5_10 = Data4_5_10[:,2]
model_normalization4_5_10 = Data4_5_10[:,3]

# %% [markdown]
# ## First Coulmn

# %%
# Now switch to a more OO interface to exercise more features.
fig, axs = plt.subplots(nrows=5, ncols=4, sharex=True)

ax = axs[0,0]
ax.errorbar(phase1_03_1new, intensity1_03_1new, xerr=bin_simi_width1_03_1new, yerr=model_normalization1_03_1new,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '0.3-1 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")

# With 4 subplots, reduce the number of axis ticks to avoid crowding.
ax.locator_params(nbins=4)

ax = axs[1,0]
ax.errorbar(phase1_1_2, intensity1_1_2, xerr=bin_simi_width1_1_2, yerr=model_normalization1_1_2,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '1-2 keV')


ax = axs[2,0]
ax.errorbar(phase1_2_3, intensity1_2_3, xerr=bin_simi_width1_2_3, yerr=model_normalization1_2_3,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '2-3 keV')

ax = axs[3,0]
ax.set_yscale('log')
ax.errorbar(phase1_3_5, intensity1_3_5, xerr=bin_simi_width1_3_5, yerr=model_normalization1_3_5,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '3-5 keV')

ax = axs[4,0]
ax.set_yscale('log')
ax.errorbar(phase1_5_10, intensity1_5_10, xerr=bin_simi_width1_5_10, yerr=model_normalization1_5_10,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '5-10 keV')


#fig.suptitle('Variable errorbars') 
#plt.savefig('SWJ1818_pulse_profile_new.pdf', bbox_inches = 'tight')
#fig.show()

ax = axs[0,1]
ax.errorbar(phase2_03_10new, intensity2_03_10new, xerr=bin_simi_width2_03_10new, yerr=model_normalization2_03_10new,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='red', mew = 2, ms=3, color='red', label = '0.3-1 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")

# With 4 subplots, reduce the number of axis ticks to avoid crowding.
ax.locator_params(nbins=4)


ax = axs[1,2]
#ax.errorbar(phase2_03_2new, intensity2_03_2new, xerr=bin_simi_width2_03_2new, yerr=model_normalization2_03_2new,
#          fmt = '.', fillstyle = 'none', mec='green', mew = 2, ms=3, color='green', label = '1-2 keV')


ax = axs[2,1]
ax.errorbar(phase2_2_3, intensity2_2_3, xerr=bin_simi_width2_2_3, yerr=model_normalization2_2_3,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='red', mew = 2, ms=3, color='red', label = '2-3 keV')

ax = axs[3,1]
ax.set_yscale('log')
ax.errorbar(phase2_3_5, intensity2_3_5, xerr=bin_simi_width2_3_5, yerr=model_normalization2_3_5,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='red', mew = 2, ms=3, color='red', label = '3-5 keV')

ax = axs[4,1]
ax.set_yscale('log')
ax.errorbar(phase2_5_10, intensity2_5_10, xerr=bin_simi_width2_5_10, yerr=model_normalization2_5_10,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='red', mew = 2, ms=3, color='red', label = '5-10 keV')



# Now switch to a more OO interface to exercise more features.
#fig, axs = plt.subplots(nrows=5, ncols=4, sharex=True)

ax = axs[0,2]
ax.errorbar(phase3_03_10new, intensity3_03_10new, xerr=bin_simi_width3_03_10new, yerr=model_normalization3_03_10new,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='green', mew = 2, ms=3, color='green', label = '0.3-1 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")

# With 4 subplots, reduce the number of axis ticks to avoid crowding.
ax.locator_params(nbins=4)

ax = axs[1,2]
ax.errorbar(phase3_03_2new, intensity3_03_2new, xerr=bin_simi_width3_03_2new, yerr=model_normalization3_03_2new,
           fmt = '.', fillstyle = 'none', mec='green', mew = 2, ms=3, color='green', label = '1-2 keV')


ax = axs[2,2]
ax.errorbar(phase3_2_3, intensity3_2_3, xerr=bin_simi_width3_2_3, yerr=model_normalization3_2_3,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='green', mew = 2, ms=3, color='green', label = '2-3 keV')

ax = axs[3,2]
ax.set_yscale('log')
ax.errorbar(phase3_3_5, intensity3_3_5, xerr=bin_simi_width3_3_5, yerr=model_normalization3_3_5,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='green', mew = 2, ms=3, color='green', label = '3-5 keV')

ax = axs[4,2]
ax.set_yscale('log')
ax.errorbar(phase3_5_10, intensity3_5_10, xerr=bin_simi_width3_5_10, yerr=model_normalization3_5_10,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='green', mew = 2, ms=3, color='green', label = '5-10 keV')


#fig.suptitle('Variable errorbars') 
#plt.savefig('SWJ1818_pulse_profile_new.pdf', bbox_inches = 'tight')
#fig.show()


ax = axs[0,3]
ax.errorbar(phase4_03_10new, intensity4_03_10new, xerr=bin_simi_width4_03_10new, yerr=model_normalization4_03_10new,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='blue', mew = 2, ms=3, color='blue', label = '0.3-1 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")

# With 4 subplots, reduce the number of axis ticks to avoid crowding.
ax.locator_params(nbins=4)

ax = axs[1,3]
#ax.errorbar(phase4_1_2, intensity4_1_2, xerr=bin_simi_width4_1_2, yerr=mode1_normalization4_1_2,
#            fmt = '.', fillstyle = 'none', mec='blue', mew = 2, ms=3, color='blue', label = '1-2 keV')


ax = axs[2,3]
ax.errorbar(phase4_2_3, intensity4_2_3, xerr=bin_simi_width4_2_3, yerr=model_normalization4_2_3,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='blue', mew = 2, ms=3, color='blue', label = '2-3 keV')

ax = axs[3,3]
ax.set_yscale('log')
ax.errorbar(phase4_3_5, intensity4_3_5, xerr=bin_simi_width4_3_5, yerr=model_normalization4_3_5,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='blue', mew = 2, ms=3, color='blue', label = '3-5 keV')

ax = axs[4,3]
ax.set_yscale('log')
ax.errorbar(phase4_5_10, intensity4_5_10, xerr=bin_simi_width4_5_10, yerr=model_normalization4_5_10,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='blue', mew = 2, ms=3, color='blue', label = '5-10 keV')


fig.suptitle('SWJ1818 Pulse Profile') 
fig.savefig('SWJ1818_pulse_profile_new.pdf', bbox_inches = 'tight')
fig.show()
# Out:
# <ipython-input-388-fd2d1f4e53ea>:132: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
ax = axs[0,0]
ax.errorbar(phase1_03_10new, intensity1_03_10new, xerr=bin_simi_width1_03_10new, yerr=model_normalization1_03_10new,
            fmt = '.', fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '0.3-1 keV')
ax.set_title("Simplest errorbars, 0.2 in x, 0.4 in y")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.yscale('log')

plt.errorbar(phase1_3_5, intensity1_3_5, xerr=bin_simi_width1_3_5, yerr=model_normalization1_3_5,
            fmt = "ks-", fillstyle = 'none', linestyle='-', drawstyle='steps-mid', mec='black', mew = 2, ms=3, color='black', label = '3-5 keV')
plt.show()

# %%
#drawStyles = {'default': '_draw_lines', 'steps': '_draw_steps_pre', 'steps-mid': '_draw_steps_mid', 
#              'steps-post': '_draw_steps_post', 'steps-pre': '_draw_steps_pre'}
